# %%
import pandas as pd
import scipy
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('../samples/folk_sample_lyrics.csv')
# plt.scatter(data['Count'], data['Diversity'])
plt.hist(data['Count'], bins=100)
# plt.xlim((0, 300))
plt.xlabel('Listens')
plt.ylabel('Count')
plt.show()

# %%
data.describe()
# Out:
#               Count
# count  5.000000e+02
# mean   4.909305e+07
# std    9.538333e+07
# min    2.335400e+04
# 25%    4.497746e+06
# 50%    1.503834e+07
# 75%    4.992400e+07
# max    1.021485e+09

# %% [markdown]
# Our minimum and maximum is 9700000 and 1750000000 respectively. So, we can see if there is any patterns for more than a certain amount of play

# %%
from sklearn.feature_extraction.text import CountVectorizer

# filtering stop words
import re
from nltk.corpus import stopwords
stopwords_eng = stopwords.words('english')

data['Lyrics'] = data['Lyrics'].apply(lambda x : x.lower())
data['Lyrics'] = data['Lyrics'].apply(lambda x : re.sub(r'\d+','', x))
data['Lyrics'] = data['Lyrics'].apply(lambda x : ' '.join([word for word in re.split(r'[\W_]' ,x) if word not in stopwords_eng]))
data['Lyrics'] = data['Lyrics'].apply(lambda x : re.sub(r"i'm",'', x))
data['Lyrics'] = data['Lyrics'].apply(lambda x : re.sub(r"you",'', x))
data['Lyrics'] = data['Lyrics'].apply(lambda x : re.sub(r"yeah",'', x))
data['Lyrics'] = data['Lyrics'].apply(lambda x : re.sub(r"oh+",'', x))
data['Lyrics'] = data['Lyrics'].apply(lambda x : re.sub(r"like",'', x))

# %%
def extract_features(df):
    vectorizer = CountVectorizer()
    results = vectorizer.fit_transform(df)
    print(vectorizer.get_feature_names())
    return results, vectorizer

counts, vectorizer = extract_features(data['Lyrics'])
# Out:
# ['aa', 'aaa', 'aaaaaa', 'aaah', 'aamenen', 'ab', 'abandon', 'abandoned', 'abase', 'abate', 'abbey', 'abbots', 'abdul', 'aberdeen', 'abeyance', 'abide', 'abides', 'ability', 'ablative', 'ablaze', 'able', 'abler', 'abominable', 'abound', 'abroad', 'absence', 'absinthe', 'absolute', 'absolutely', 'abstraction', 'absurd', 'absurdists', 'absurdity', 'abuse', 'abused', 'abyss', 'acacias', 'academe', 'academic', 'acapulco', 'acc', 'accent', 'accept', 'acceptance', 'accepted', 'accepting', 'accident', 'accidents', 'accommodate', 'accomplice', 'accomplish', 'accomplished', 'accord', 'according', 'accords', 'account', 'accountability', 'accoutrements', 'accrochs', 'accumulated', 'accusations', 'accuse', 'accused', 'accuser', 'accustomed', 'ace', 'ache', 'ached', 'aches', 'achievable', 'achieved', 'achievement', 'achin', 'aching', 'acid', 'acidosis', 'acknowledged', 'acquired', 'acquisition', 'acres', 'acronym', 'across', 'acrost', 'act', 'acted', 'acting', 'action', 'actions', 'activating', 'active', 'activity', 'actress', 'actual', 'actually', 'acute', 'ad', 'adage', 'adam', 'adams', 'add', 'added', 'addition', 'address', 'addressed', 'addresses', 'adit', 'administry', 'admire', 'admired', 'admission', 'admissions', 'admit', 'admitting', 'adore', 'adoring', 'adrift', 'adulterer', 'advance', 'advanced', 'advances', 'advantage', 'advent', 'advertisement', 'advice', 'advise', 'advised', 'aedificat', 'aehiilrs', 'aesthetic', 'afar', 'affair', 'affairs', 'affect', 'affection', 'affectionately', 'affections', 'affects', 'affiance', 'affianced', 'affirmation', 'affirmations', 'affirmed', 'affirms', 'affluent', 'afflux', 'afford', 'afire', 'afloat', 'afm', 'afraid', 'afree', 'africa', 'african', 'afrika', 'aft', 'aftermath', 'afternoon', 'afternoons', 'aftertime', 'afterward', 'afterwards', 'agates', 'age', 'agents', 'ages', 'aghast', 'agincourt', 'aging', 'agitprop', 'aglaa', 'aglow', 'ago', 'agony', 'agree', 'agreed', 'agrees', 'agrin', 'agrippina', 'ah', 'aha', 'ahead', 'ahh', 'ahhaaaaa', 'ahhh', 'ahhhh', 'ahhhhh', 'ahhhhhh', 'ahhhhhhhh', 'ahua', 'ai', 'aid', 'aiding', 'aim', 'aimlessly', 'aims', 'aint', 'air', 'airing', 'airplanes', 'airy', 'aisle', 'aisles', 'aki', 'akin', 'al', 'ala', 'alabama', 'alan', 'alarm', 'alarmed', 'alas', 'albeit', 'albert', 'album', 'albums', 'albuquerque', 'alcol', 'alcolic', 'aldrig', 'alexander', 'alfred', 'algebra', 'alhazred', 'alibis', 'alien', 'alight', 'align', 'aligned', 'alignment', 'alive', 'alleged', 'allegedly', 'alleghanies', 'allegory', 'allen', 'alley', 'alleys', 'alleyway', 'alleyways', 'allnight', 'allowd', 'allowed', 'allures', 'allusion', 'ally', 'almighty', 'almond', 'almonds', 'almost', 'alms', 'alo', 'aloft', 'alone', 'along', 'alongside', 'aloud', 'aloysius', 'alpine', 'already', 'alright', 'also', 'altar', 'alter', 'altered', 'alters', 'although', 'always', 'amateurish', 'amaze', 'amazed', 'amazin', 'amazing', 'amazon', 'ambassadors', 'ambassadresses', 'amber', 'ambien', 'ambling', 'ambrose', 'ambrosia', 'ambrosial', 'ambulance', 'amen', 'amending', 'america', 'american', 'americas', 'amid', 'amie', 'ammonites', 'among', 'amongst', 'amoral', 'amorous', 'amount', 'amounts', 'ample', 'amplifier', 'amused', 'amusement', 'amusing', 'amygdaloid', 'analytics', 'anametamystikhood', 'anarchic', 'anarchist', 'anarchy', 'anatomic', 'anatomy', 'anchor', 'anchored', 'anchors', 'ancient', 'ancients', 'andalusian', 'andra', 'andreas', 'andy', 'aneris', 'aneristic', 'angel', 'angeles', 'angels', 'anger', 'angie', 'angle', 'angled', 'angrily', 'angry', 'animal', 'animalistic', 'animals', 'animum', 'anion', 'ankle', 'ann', 'annals', 'annan', 'annex', 'annihilation', 'annotated', 'announce', 'annoying', 'anointed', 'anon', 'anonymous', 'another', 'answer', 'answered', 'answering', 'answers', 'antagonisms', 'antagonistic', 'antennaes', 'anthem', 'anthology', 'anthony', 'anthropologist', 'anthropologists', 'anti', 'antithesis', 'anton', 'antone', 'ants', 'anvil', 'anvils', 'anxieties', 'anxiety', 'anxious' ...

# %%
# Plot most common features
def plot_most_common(counts, vectorizer, number_words):
    import seaborn as sns
    words = vectorizer.get_feature_names()
    total_counts = np.zeros(len(words))
    for t in counts:
        total_counts+=t.toarray()[0]
    count_dict = (zip(words, total_counts))
    count_dict = sorted(count_dict, key=lambda x: x[1], reverse=True)[0:number_words]
    words = [w[0] for w in count_dict]
    counts = [w[1] for w in count_dict]
    x_pos = np.arange(len(words)) 

    plt.figure(2, figsize=(15, 15/1.6180))
    plt.subplot(title='{} most common words'.format(number_words))
    sns.set_context("notebook", font_scale=1.25, rc={"lines.linewidth": 2.5})
    sns.barplot(x_pos, counts, palette='husl')
    plt.xticks(x_pos, words, rotation=90) 
    plt.xlabel('words')
    plt.ylabel('counts')
    plt.show()
    
plot_most_common(counts, vectorizer, 20)

# %%
from sklearn.decomposition import LatentDirichletAllocation as LDA

 
# Helper function
def print_topics(model, count_vectorizer, n_top_words):
    words = count_vectorizer.get_feature_names()
    for topic_idx, topic in enumerate(model.components_):
        print("\nTopic #%d:" % topic_idx)
        print(" ".join([words[i]
                        for i in topic.argsort()[:-n_top_words - 1:-1]]))
        
number_topics = 2
number_words = 20# Create and fit the LDA model
lda = LDA(n_components=number_topics, n_jobs=-1)
lda.fit(counts)# Print the topics found by the LDA model
print("Topics found via LDA:")
print_topics(lda, vectorizer, number_words)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/sklearn/decomposition/online_lda.py:536: DeprecationWarning: The default value for 'learning_method' will be changed from 'online' to 'batch' in the release 0.20. This warning was introduced in 0.18.
#   DeprecationWarning)
# Topics found via LDA:
#
# Topic #0:
# love la know go one heart time come see could man let well away back home get never lie way
#
# Topic #1:
# said would one know hey way father mr could see back little time say day people big made come stephen
